# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaskarnainwal/tuples-set-and-dictionary-pdf/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create a Tuple

my_tuple = (1,'a',3)

print(my_tuple)


(1, 'a', 3)


type(my_tuple)


tuple


#Can also mix object types

another_tuple=('one',2,4.53,'abc')


#Show
another_tuple


('one', 2, 4.53, 'abc')


my_list = [1]

type(my_list)


list


my_tuple =(1,)

type(my_tuple)


tuple


my_tuple=(1,2,3,4)

len(my_tuple)


4


#Tuple Indexing


print(another_tuple)


('one', 2, 4.53, 'abc')


another_tuple[-3]


2


#Tuple Slicing

print(another_tuple)


('one', 2, 4.53, 'abc')


another_tuple[1:3]


(2, 4.53)


another_tuple[2:]


(4.53, 'abc')


another_tuple[:6]


('one', 2, 4.53, 'abc')


another_tuple[-4:]


('one', 2, 4.53, 'abc')


len(another_tuple)


4


#Tuple Methods

#index()

my_tuple=(1,2,3,4,5,6,1,2,1,3)

my_tuple.index(2)


1


#count()

my_tuple.count(2)


2


#Immutability

print(my_tuple)


(1, 2, 3, 4, 5, 6, 1, 2, 1, 3)


my_tuple[0]


1


#Create a list
my_list=[5,7,9,3,2]

#Replace the first element with the value 1]
my_list[0]=1

#Our modified list
my_list


[1, 7, 9, 3, 2]


#Sets

my_set{(2,3),1,2}


#we add two sets with the add() method

my_set=set()
my_set.add('a')

#Show

my_set


{'a'}


#Remove

non_empty_set={1,5,6,73,2}

non_empty_set.remove(5)

non_empty_set


{1, 2, 6, 73}


#union

#Initialize sets A and B
A={1,2,3,4,5}
B={4,5,6,7,8}

A.union(B)


{1, 2, 3, 4, 5, 6, 7, 8}


#Intersection

A.intersection(B)


{4, 5}


#difference

A.difference(B)


{1, 2, 3}


#symmetric_difference()

A.symmetric_difference(B)


{1, 2, 3, 6, 7, 8}


#Dictionaries

marvel_dict={'Name':'Thor','Place':'Asgard','Weapon':'Hammer'}

marvel_dict['Place']


'Asgard'


marvel_dict['Name']


'Thor'


#Dictionary methods


#keys()

marvel_dict.keys()


dict_keys(['Name', 'Place', 'Weapon'])


list(marvel_dict.keys())


['Name', 'Place', 'Weapon']


#Values

list(marvel_dict.values())


['Thor', 'Asgard', 'Hammer']


#Items()

list(marvel_dict.items())


[('Name', 'Thor'), ('Place', 'Asgard'), ('Weapon', 'Hammer')]


#get()

marvel_dict.get('Place')


'Asgard'
# Out:
#   File "<ipython-input-2-4435a1d26f9c>", line 155
#     my_set{(2,3),1,2}
#           ^
# SyntaxError: invalid syntax
